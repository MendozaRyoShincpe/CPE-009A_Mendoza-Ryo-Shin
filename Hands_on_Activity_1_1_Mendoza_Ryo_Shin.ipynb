# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRyoShincpe/CPE-009A_Mendoza-Ryo-Shin/blob/main/Hands_on_Activity_1_1_Mendoza_Ryo_Shin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Hands-on Activity 1.1 Literals, Operators, and Variables**

# %% [markdown]
# **Name**: Mendoza, Ryo Shin P.
#
# **Section**: CPE12S2
#
# **Date**: January 8, 2026

# %% [markdown]
# # **Assigning variables of different data types in Python**

# %% [markdown]
# 1. In an empty cell, declare a variable value and assign it the value of 5 then display its value using print().

# %%
value = 5
print(value)
# Out:
# 8

# %% [markdown]
# 2. Create a new cell and type the command: type(value) then run the cell. The output should be like the image  below.

# %%
print(type(value))
# Out:
# <class 'int'>

# %% [markdown]
# 3. In a new cell, use the same variable value and assign it the value of 5.0 then print the value.

# %%
value = 5.0
print(value)

# %% [markdown]
#  4. Repeat step 2.

# %%
print(type(value))
# Out:
# <class 'int'>

# %% [markdown]
# 5. Repeat these steps for the following values:
#
# a. 2+3j
#
# b. ‘Hello World’
#
# c. “Hello World”
#
# d. True
#
# e. False
#
# f. [1,2,3,4,5]
#
# g. (1,2,3,4,5)
#
# h. { ‘name’: ‘Your_name’ }
#
# i. None

# %%
# Step 5(a): Assign complex number
value = 2 + 3j
print(value)
print(type(value))
# Out:
# (2+3j)
# <class 'complex'>

# %%
# Step 5b: Assign string with single quotes
value = 'Hello World'
print(value)
print(type(value))
# Out:
# Hello World
# <class 'str'>

# %%
# Step 5c: Assign string with double quotes
value = "Hello World"
print(value)
print(type(value))
# Out:
# Hello World
# <class 'str'>

# %%
# Step 5d: Assign boolean with "True"
value = True
print(value)
print(type(value))
# Out:
# False
# <class 'bool'>

# %%
# Step 5e: Assign boolean with "False"
value = False
print(value)
print(type(value))
# Out:
# False
# <class 'bool'>

# %%
# Step 5f: Assign list
value = [1, 2, 3, 4, 5]
print(value)
print(type(value))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
# Step 5g: Assign tuple
value = (1, 2, 3, 4, 5)
print(value)
print(type(value))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
# Step 5h: Assign dictionary
value = {'Mendoza': 'Ryo Shin'}
print(value)
print(type(value))
# Out:
# {'Mendoza': 'Ryo Shin'}
# <class 'dict'>

# %%
# Step 5i: Assign None
value = None
print(value)
print(type(value))
# Out:
# None
# <class 'NoneType'>

# %%
# Step 6: Re-assign value to 5
value = 5
print(value)
print(type(value))
# Out:
# 5
# <class 'int'>

# %%
# Step 7: Declare new variable value2
value2 = -6
print(value2)
print(type(value2))
# Out:
# -6
# <class 'int'>

# %% [markdown]
# # **Performing Operations with Python**

# %% [markdown]
# 1. Using value and value2. Type the command: print(value+value2)

# %%
value, value2 = 5, -6
print(value + value2)
# Out:
# -1

# %% [markdown]
# 2. Repeat step 1 for the following values of value and value2:

# %%
# a. Float and Integer
value, value2 = 5.0, 6
print(value + value2)
# Out:
# 11.0

# %%
# b. Negative Integer and Float
value, value2 = -5, 6.1
print(value + value2)
# Out:
# 1.0999999999999996

# %%
# c. Strings (seperated with space)
value, value2 = "Hello", "world"
print(value + " " + value2)
# Out:
# Hello world

# %%
# d. Lists
value, value2 = [1, 2, 3], [4, 5, 6]
print(value + value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# e. Tuples
value, value2 = (1, 2, 3), (4, 5, 6)
print(value, value2)
# Out:
# (1, 2, 3) (4, 5, 6)

# %%
# f. Dictionaries
value, value2 = {"Mendoza": "Ryo Shin"}, {"Age:": 18}
value.update(value2)
print(value)
# Out:
# {'Mendoza': 'Ryo Shin', 'Age:': 18}

# %% [markdown]
# 3. Using value, value2 = 30, 4. Type the commands:
#
# a. print(value*value2)
#
# b. print(value2**2)
#
# c. print(value2**3)
#
# d. print(value*value2+value2**2+1)
#
# e. print(value/value2)
#
# f. print(value%value2)

# %%
value, value2 = 30, 4

# a. Multiplication
print(value * value2)

# b. Exponentiation (square)
print(value2 ** 2)

# c. Exponentiation (cube)
print(value2 ** 3)

# d. Combined expression
print(value * value2 + value2 ** 2 + 1)

# e. Division
print(value / value2)

# f. Modulo (remainder)
print(value % value2)
# Out:
# 120
# 16
# 64
# 137
# 7.5
# 2

# %% [markdown]
# # **# Assigning Input Data to a Variable (BMI)**

# %%
name = str(input("Enter your name:"))
weight = float(input("Enter your weight(kg):"))
height = float(input("Enter your height(m):"))
bmi = float(weight / (height **2))
print()
print ("Name:", name)
print ("Weight:", weight)
print ("Height", height)
print ("BMI:", bmi)
# Out:
# Enter your name:Ryo Shin Mendoza
# Enter your weight(kg):53
# Enter your height(m):1.6764
#
# Name: Ryo Shin Mendoza
# Weight: 53.0
# Height 1.6764
# BMI: 18.85908271357406

# %% [markdown]
# # **Supplemetary Activity**

# %% [markdown]
# 1. Write the Python equivalent code of the following C code

# %%
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

area = 0.5 * base * height

print("The area of the triangle is", area)
# Out:
# Enter the base of the triangle: 8
# Enter the height of the triangle: 11
# The area of the triangle is 44.0

# %% [markdown]
# Write a program that would convert Celsius to Fahrenheit given the formula: F = (C × 9/5) + 32

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 30
# Temperature in Fahrenheit: 86.0

# %% [markdown]
# Write a program that can determine the distance between two points given the coordinates using the  formula:

# %%
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = ((x2 - x1)**2 + (y2 - y1)**2) ** 0.5

print("The distance between the two points is:", distance)
# Out:
# Enter x1: 3
# Enter y1: 4
# Enter x2: 5
# Enter y2: 6
# The distance between the two points is: 2.8284271247461903
