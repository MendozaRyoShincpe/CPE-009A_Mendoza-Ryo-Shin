# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRyoShincpe/CPE-009A_Mendoza-Ryo-Shin/blob/main/Hands_on_Activty_4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hands-on Activity 4.1
#
# By: Mendoza, Ryo Shin P.
#
# Section: CPE12S2

# %% [markdown]
# Supplementary Activity

# %%
# Number 1
def word_filter(sentence, bad_words):
    for word in bad_words:
        sentence = sentence.replace(word, "*" * len(word))
    return sentence

print(word_filter("This is a bad example", ["bad"]))
# Out:
# This is a *** example

# %%
# Number 2
import math

def projectilemotion_solver(v, angle_deg, g=9.8):
    angle_rad = math.radians(angle_deg)
    R = (v**2 * math.sin(2 * angle_rad)) / g
    h = (v**2 * (math.sin(angle_rad))**2) / (2 * g)
    return R, h

# Example
range_, height = projectilemotion_solver(11, 20)
print("Range:", range_)
print("Max Height:", height)
# Out:
# Range: 7.936459262456249
# Max Height: 0.7221587342500931

# %%
# Number 3
import math

def quadratic_solver(a, b, c):
    d = b**2 - 4*a*c
    if d < 0:
        roots = "No real roots"
    else:
        root1 = (-b + math.sqrt(d)) / (2*a)
        root2 = (-b - math.sqrt(d)) / (2*a)
        roots = (root1, root2)

    with open("quadratic_input.txt", "w") as f_in:
        f_in.write(f"a={a}, b={b}, c={c}\n")
    with open("quadratic_output.txt", "w") as f_out:
        f_out.write(str(roots))

    return roots

print(quadratic_solver(1, -3, 2))
# Out:
# (2.0, 1.0)
