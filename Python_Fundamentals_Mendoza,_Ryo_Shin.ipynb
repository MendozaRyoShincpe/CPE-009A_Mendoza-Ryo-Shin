# %% [markdown]
# <a href="https://colab.research.google.com/github/MendozaRyoShincpe/CPE-009A_Mendoza-Ryo-Shin/blob/main/Python_Fundamentals_Mendoza%2C_Ryo_Shin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Indentation**

# %%
if 5 > 2:
  print ("FIVE IS GREATER THAN TWO!")
# Out:
# FIVE IS GREATER THAN TWO!

# %% [markdown]
# **Python Comment**

# %%
#This is a comment
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Python Variable**

# %%
x = 1
a, b = 0, -1
a, b, c=0,-1,2 #SINGLE LINE OF CODE, VARIABLE = VALUE
print (a * b + c)
# Out:
# 2

# %%
#Others:
x = 1
a, b = 0, -1
a, b, c=0,-1,2 #SINGLE LINE OF CODE, VARIABLE = VALUE
b = "SALLY" #This is a type of string
print (b)
# Out:
# SALLY

# %% [markdown]
# **Casting**

# %%
b = "sally" #This is a type of string
b = int(4)
print (b)

b = float(4)
print (b)
# Out:
# 4
# 4.0

# %% [markdown]
# **Type() Function**

# %%
x = 5
y = "Ryo"
print (type(x)) #"type" shows what data type it is
print (type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **"Double Quotes" or 'Single' quotes**

# %%
#String variables can be declared either by using by using single or double quotes

y = "John"
y = 'John'

print(y)
# Out:
# John

# %% [markdown]
# **Case Sensitive**

# %%
a = 4
A = "Ryo"

print(a)
print(A)
# Out:
# 4
# Ryo

# %% [markdown]
# **Multiple Variables**

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# **One Value to Multiple Varibles**

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# **Output Variables**

# %%
x = "enjoying"
print ("Python Programming is " + x)

#Other way:

x = "Python is "
y = "enjoying"
z = x + y
print (z)
# Out:
# Python Programming is enjoying
# Python is enjoying

# %% [markdown]
# **Arithmetic Operations**

# %%
# Addition
x = 5
y = 3
print (x + y)

x = 5
y = 3
sum = x + y
print (sum)

# Subtraction
x = 5
y = 3
print (x - y)

# Multiplication
x = 5
y = 3
print (x * y)

# Division
x = 5
y = 3
print (x / y)

# Modulus
x = 5
y = 3
print (x % y)

# Exponentation
x = 5
y = 3
print (x ** y)

# Floor Division
x = 5
y = 3
print (x // y)
# Out:
# 8
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %% [markdown]
# **Assignment Operators**

# %%
s = 1
s += 3
print (s)

s = 1
s -= 3
print (3)

s = 1
s *= 3
print (s)

s = 1
s /= 3
print (s)

s = 1
s %= 3
print (s)

s = 1
s //= 3
print (s)

s = 1
s **= 3
print (s)

s = 1
s &= 3
print (s)

s = 1
s |= 3
print (s)

s = 1
s ^= 3
print (s)

s = 1
s >>= 3
print (s)

s = 1
s <<= 3
print (s)
# Out:
# 4
# 3
# 3
# 0.3333333333333333
# 1
# 0
# 1
# 1
# 3
# 2
# 0
# 8

# %% [markdown]
# **Comparison Operators**

# %%
t = 1
u = 2

print (t == u)
print (t != u)
print (t > u)
print (t < u )
print (t >= u)
print (t <= u)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# **Logical Operators**

# %%
t = 1
u = 2

print (t < 5 and t < 10)
print (t < 5 or t < 4)
print (not(t < 5 and t < 10))
# Out:
# True
# True
# False

# %% [markdown]
# Indentity Operators

# %%
t = 1
u = 2

print (t is u)
print (x is not y)
# Out:
# False
# True

# %% [markdown]
# Bitwise Operator

# %%
v = 2 #0010

print (v << 1) #The output is 4 because 0100 shifted to the left
print (v << 2) #1000
print (1 & 2) #0000
print (15 & 15) #1111
# Out:
# 4
# 8
# 0
# 15
